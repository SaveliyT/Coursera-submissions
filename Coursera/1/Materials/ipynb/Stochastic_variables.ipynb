# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# # Нормальное распределение

# %% [markdown]
# Вот так можно сгенерировать выборку из нормально распределённой случайной величины с параметрами $\mu=2.0$ и $\sigma=0.5$:

# %%
mu = 2.0
sigma = 0.5

# зададим нормально распределенную случайную величину
norm_rv = sts.norm(loc=mu, scale=sigma)

# сгенерируем 10 значений
norm_rv.rvs(size=10)
# Out:
# array([ 2.25038354,  1.9155192 ,  2.62522278,  2.19700628,  2.01177299,
#         1.60873702,  1.69753377,  1.61726611,  1.82919136,  2.38521244])

# %% [markdown]
# Параметр ```loc``` задаёт $\mu$, ```scale``` — среднеквадратичное отклонение $\sigma$, ```size``` — размер выборки. Имя параметра ```size``` при вызове функции ```rvs``` можно не писать.
#
# Следующая функция возвращает значение функции распределения нормальной случайной величины в точке, соответствующей её аргументу:

# %%
norm_rv.cdf(3)
# Out:
# 0.97724986805182079

# %% [markdown]
# Построим график функции распределения:

# %%
x = np.linspace(0,4,100)
cdf = norm_rv.cdf(x) # функция может принимать и вектор (x)
plt.plot(x, cdf)
plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %% [markdown]
# А так можно вычислить значение функции плотности вероятности нормального распределения в заданной точке:

# %%
norm_rv.pdf(3)
# Out:
# 0.10798193302637613

# %% [markdown]
# Построим график функции плотности вероятности:

# %%
x = np.linspace(0,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
print pdf
# Out:
# [  2.67660452e-04   3.68590605e-04   5.04276112e-04   6.85419746e-04
#    9.25569229e-04   1.24172460e-03   1.65502951e-03   2.19154443e-03
#    2.88309463e-03   3.76817962e-03   4.89292294e-03   6.31203263e-03
#    8.08973277e-03   1.03006160e-02   1.30303565e-02   1.63762131e-02
#    2.04472422e-02   2.53641367e-02   3.12585990e-02   3.82721634e-02
#    4.65543853e-02   5.62603283e-02   6.75473021e-02   8.05708292e-02
#    9.54798526e-02   1.12411237e-01   1.31483663e-01   1.52791060e-01
#    1.76395772e-01   2.02321707e-01   2.30547740e-01   2.61001702e-01
#    2.93555276e-01   3.28020149e-01   3.64145740e-01   4.01618792e-01
#    4.40065071e-01   4.79053317e-01   5.18101543e-01   5.56685616e-01
#    5.94250006e-01   6.30220419e-01   6.64017960e-01   6.95074350e-01
#    7.22847660e-01   7.46837948e-01   7.66602188e-01   7.81767862e-01
#    7.92044627e-01   7.97233559e-01   7.97233559e-01   7.92044627e-01
#    7.81767862e-01   7.66602188e-01   7.46837948e-01   7.22847660e-01
#    6.95074350e-01   6.64017960e-01   6.30220419e-01   5.94250006e-01
#    5.56685616e-01   5.18101543e-01   4.79053317e-01   4.40065071e-01
#    4.01618792e-01   3.64145740e-01   3.28020149e-01   2.93555276e-01
#    2.61001702e-01   2.30547740e-01   2.02321707e-01   1.76395772e-01
#    1.52791060e-01   1.31483663e-01   1.12411237e-01   9.54798526e-02
#    8.05708292e-02   6.75473021e-02   5.62603283e-02   4.65543853e-02
#    3.82721634e-02   3.12585990e-02   2.53641367e-02   2.04472422e-02
#    1.63762131e-02   1.30303565e-02   1.03006160e-02   8.08973277e-03
#    6.31203263e-03   4.89292294e-03   3.76817962e-03   2.88309463e-03
#    2.19154443e-03   1.65502951e-03   1.24172460e-03   9.25569229e-04
#    6.85419746e-04   5.04276112e-04   3.68590605e-04   2.67660452e-04]

# %% [markdown]
# # Равномерное распределение на отрезке

# %% [markdown]
# Вот так можно сгенерировать выборку из случайной величины, имеющей равномерное распределение на отрезке $[a,b]$:

# %%
a = 1
b = 4

# обратите внимание, что в этой функции задается левая граница и масштаб, а не левая и правая границы:
uniform_rv = sts.uniform(a, b-a)

uniform_rv.rvs(10)
# Out:
# array([ 3.22339851,  3.82869457,  3.70184272,  3.15153852,  2.18143498,
#         2.74585301,  2.44760177,  1.32842104,  2.58124693,  1.30755346])

# %% [markdown]
# А так — вычислять значения функций распределения и плотностей:

# %%
x = np.linspace(0,5,100)
cdf = uniform_rv.cdf(x)
plt.plot(x, cdf)

plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %%
x = np.linspace(0,5,1000)
pdf = uniform_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Распределение Бернулли

# %% [markdown]
# Генерация выборок из распределения Бернулли с заданным параметром $p$:

# %%
bernoulli_rv = sts.bernoulli(0.7)

bernoulli_rv.rvs(10)
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 1, 1, 1])

# %% [markdown]
# # Биномиальное распределение

# %% [markdown]
# Генерация выборок из биномиального распределения:

# %%
binomial_rv = sts.binom(20, 0.7)
binomial_rv.rvs(10)
# Out:
# array([12, 12, 12, 14, 15, 13, 13, 11, 14, 16])

# %% [markdown]
# Первый аргумент функции binom — значение параметра $n$, второй — параметра $p$.
#
# Функция распределения:

# %%
x = np.linspace(0,20,21)
cdf = binomial_rv.cdf(x)
plt.step(x, cdf)

plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %% [markdown]
# Функция вероятности ```pmf``` для дискретных случайных величин заменяет функцию плотности ```pdf```:

# %%
x = np.linspace(0,20,21)
pmf = binomial_rv.pmf(x)
plt.plot(x, pmf, 'o')

plt.ylabel('$P(X=x)$')
plt.xlabel('$x$')

# %% [markdown]
# Посмотрим, как ведут себя биномиально распределенные величины при разных значениях параметров:

# %%
x = np.linspace(0,45,46)
for N in [20, 30]:
    for p in [0.2, 0.7]:
        rv = sts.binom(N, p)
        cdf = rv.cdf(x)
        plt.step(x, cdf, label="$N=%s, p=%s$" % (N,p))
plt.legend()
plt.title("CDF (binomial)")

plt.ylabel('$F(X)$')
plt.xlabel('$x$')

# %%
x = np.linspace(0,45,46)
symbols = iter(['o', 's', '^', '+'])
for N in [20, 30]:
    for p in [0.2, 0.8]:
        rv = sts.binom(N, p)
        pmf = rv.pmf(x)
        plt.plot(x, pmf, next(symbols), label="$N=%s, p=%s$" % (N,p))
plt.legend()
plt.title("PMF (binomial)")

plt.ylabel('$P(X=x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Распределение Пуассона

# %% [markdown]
# Генерация выборок из распределения Пуассона с параметром $\lambda$:

# %%
poisson_rv = sts.poisson(5)
poisson_rv.rvs(10)
# Out:
# array([7, 5, 3, 3, 5, 3, 5, 3, 4, 6])

# %%
x = np.linspace(0,30,31)
for l in [1, 5, 10, 15]:
    rv = sts.poisson(l)
    cdf = rv.cdf(x)
    plt.step(x, cdf, label="$\lambda=%s$" % l)
plt.legend()
plt.title("CDF (poisson)")

plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %%
x = np.linspace(0,30,31)

symbols = iter(['o', 's', '^', '+'])
for l in [1, 5, 10, 15]:
    rv = sts.poisson(l)
    pmf = rv.pmf(x)
    plt.plot(x, pmf, next(symbols), label="$\lambda=%s$" % l)
plt.legend()
plt.title("PMF (poisson)")

plt.ylabel('$P(X=x)$')
plt.xlabel('$x$')

# %% [markdown]
# # Дискретное распределение общего вида

# %% [markdown]
# Чтобы сгенерировать дискретную случайную величину общего вида, нужно задать множество её значений и соответствующих вероятностей и использовать функцию ```numpy.random.choice```:

# %%
elements = np.array([1, 5, 12])
probabilities = [0.05, 0.7, 0.25]
np.random.choice(elements, 10, p=probabilities)
# Out:
# array([12,  5,  5,  5,  5,  5,  5,  5,  5,  5])

# %% [markdown]
# # Другие распределения

# %% [markdown]
# Существует большое количество других стандартных семейств распределений, многие из которых также можно генерировать в Питоне.
# Например, распределение хи-квадрат $\chi^2_k$, имеющее наутральный параметр $k$, который называется числом степеней свободы:

# %%
x = np.linspace(0,30,100)
for k in [1, 2, 3, 4, 6, 9]:
    rv = sts.chi2(k)
    cdf = rv.cdf(x)
    plt.plot(x, cdf, label="$k=%s$" % k)
plt.legend()
plt.title("CDF ($\chi^2_k$)")

# %%
x = np.linspace(0,30,100)
for k in [1, 2, 3, 4, 6, 9]:
    rv = sts.chi2(k)
    pdf = rv.pdf(x)
    plt.plot(x, pdf, label="$k=%s$" % k)
plt.legend()
plt.title("PDF ($\chi^2_k$)")

# %% [markdown]
# Полный список функций SciPy для работы со всеми распределениями можно найти тут: http://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
